# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
mpl.style.use('ggplot')

# %%
df=pd.read_csv('train_u6lujuX_CVtuZ9i (1).csv')

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
data = 'train_u6lujuX_CVtuZ9i (1).csv'
df = pd.read_csv(data, usecols=[6,7,8,9,10,12])
df
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Loan_Status
# 0               1.0           Y
# 1               1.0           N
# ...

# %%
df.head()
# Out:
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Loan_Status
# 0             1.0           Y
# 1             1.0           N
# 2             1.0           Y
# 3             1.0           Y
# 4             1.0           Y

# %%
df.shape
# Out:
# (614, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ApplicantIncome    614 non-null    int64
#  1   CoapplicantIncome  614 non-null    float64
#  2   LoanAmount         592 non-null    float64
#  3   Loan_Amount_Term   600 non-null    float64
#  4   Credit_History     564 non-null    float64
#  5   Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 28.9+ KB

# %%
df.isnull().sum()
# Out:
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Loan_Status           0
# dtype: int64

# %%
backup=df.copy()

# %%
df.bfill(inplace=True)

# %%
df.isnull().sum()
# Out:
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Loan_Status          0
# dtype: int64

# %%
X=df[['ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term','Credit_History',]]
y=df['Loan_Status']

# %%
X
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0       128.0             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History
# 0               1.0
# 1               1.0
# 2               1.0
# 3               1.0
# ...

# %%
y
# Out:
# 0      Y
# 1      N
# 2      Y
# 3      Y
# 4      Y
#       ..
# 609    Y
# 610    Y
# 611    Y
# 612    Y
# 613    N
# Name: Loan_Status, Length: 614, dtype: object

# %%
y.shape
# Out:
# (614,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
X_train
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 352             2666             2083.0        95.0             360.0
# 455             3859                0.0        96.0             360.0
# 392             2583             2115.0       120.0             360.0
# 561            19484                0.0       600.0             360.0
# 79              3333             2166.0       130.0             360.0
# ..               ...                ...         ...               ...
# 270             3237                0.0        30.0             360.0
# 476             6700             1750.0       230.0             300.0
# 323             3166             2985.0       132.0             360.0
# 611             8072              240.0       253.0             360.0
# 484             8333                0.0       246.0             360.0
#
#      Credit_History
# 352             1.0
# 455             1.0
# 392             1.0
# 561             1.0
# ...

# %%
y_train
# Out:
# 352    Y
# 455    Y
# 392    Y
# 561    Y
# 79     Y
#       ..
# 270    Y
# 476    Y
# 323    Y
# 611    Y
# 484    Y
# Name: Loan_Status, Length: 491, dtype: object

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
from sklearn.preprocessing import OneHotEncoder

ohe=OneHotEncoder()
ohe.fit(X[['ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term','Credit_History',]])
#ohe.fit(y[['Loan_Status']])
# Out:
# OneHotEncoder()

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train
# Out:
# array([[-0.44396249,  0.14255484, -0.60061586,  0.27403207,  0.41453312],
#        [-0.2530769 , -0.54130867, -0.58931258,  0.27403207,  0.41453312],
#        [-0.45724288,  0.15306066, -0.31803404,  0.27403207,  0.41453312],
#        ...,
#        [-0.36396015,  0.43868776, -0.18239477,  0.27403207,  0.41453312],
#        [ 0.42102283, -0.46251499,  1.18530123,  0.27403207,  0.41453312],
#        [ 0.46278406, -0.54130867,  1.10617832,  0.27403207,  0.41453312]])

# %%
X_test
# Out:
# array([[-1.75794637e-01, -4.79258643e-01, -2.72820947e-01,
#          2.74032068e-01,  4.14533122e-01],
#        [-1.94355180e-01, -1.99869377e-01, -4.31066765e-01,
#          2.74032068e-01,  4.14533122e-01],
#        [-4.70683270e-01,  2.65669965e-01,  1.34096871e-01,
#          2.74032068e-01,  4.14533122e-01],
#        [-2.03795457e-01, -6.62484232e-02,  1.11490325e-01,
#          2.74032068e-01,  4.14533122e-01],
#        [ 1.53495003e-01, -5.41308668e-01,  5.86227779e-01,
#          2.74032068e-01,  4.14533122e-01],
#        [-4.87323757e-01, -5.41308668e-01,  2.13219780e-01,
#          2.74032068e-01,  4.14533122e-01],
#        [-3.99001171e-01,  4.99419824e-03, -8.83197673e-01,
#         -2.50209748e+00, -2.41235247e+00],
#        [ 1.89162589e+00, -5.41308668e-01,  8.68809597e-01,
#          2.74032068e-01,  4.14533122e-01],
#        [-2.60437115e-01, -5.41308668e-01, -3.63247128e-01,
#         -2.50209748e+00,  4.14533122e-01],
# ...

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
print(classifier.predict(sc.transform([[19,  19000,23,54,65]])))
# Out:
# ['Y']
# C:\Users\Hp\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
y_pred = classifier.predict(X_test)

# %%
y_test_array = y_test.to_numpy() if isinstance(y_test, (pd.DataFrame, pd.Series)) else y_test
y_pred_array = y_pred.to_numpy() if isinstance(y_pred, (pd.DataFrame, pd.Series)) else y_pred

y_test_array = y_test_array.reshape(-1, 1)
y_pred_array = y_pred_array.reshape(-1, 1)

result = np.concatenate((y_pred_array, y_test_array), axis=1)
print(result)
# Out:
# [['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['N' 'N']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'N']
#  ['Y' 'Y']
#  ['Y' 'N']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'N']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'N']
#  ['Y' 'N']
#  ['Y' 'Y']
#  ['Y' 'N']
#  ['Y' 'Y']
#  ['N' 'N']
#  ['Y' 'Y']
#  ['N' 'N']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'N']
#  ['N' 'N']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['N' 'Y']
#  ['Y' 'Y']
#  ['Y' 'N']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'N']
#  ['Y' 'Y']
#  ['N' 'N']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['N' 'N']
#  ['N' 'N']
#  ['N' 'N']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['N' 'N']
#  ['Y' 'Y']
#  ['N' 'N']
#  ['N' 'Y']
#  ['N' 'N']
#  ['Y' 'Y']
#  ['Y' 'N']
#  ['N' 'N']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['N' 'Y']
#  ['Y' 'Y']
#  ['N' 'N']
#  ['N' 'Y']
#  ['Y' 'Y']
#  ['Y' 'Y']
# ...

# %%
from sklearn.metrics import confusion_matrix, accuracy_score,precision_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[19 18]
#  [ 6 80]]
# 0.8048780487804879

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
print(classifier.predict(sc.transform([[30,87000000,0,1,1]])))
# Out:
# ['N']
# C:\Users\Hp\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
y_test_array = y_test.to_numpy() if isinstance(y_test, (pd.DataFrame, pd.Series)) else y_test
y_pred_array = y_pred.to_numpy() if isinstance(y_pred, (pd.DataFrame, pd.Series)) else y_pred

y_test_array = y_test_array.reshape(-1, 1)
y_pred_array = y_pred_array.reshape(-1, 1)

result = np.concatenate((y_pred_array, y_test_array), axis=1)
print(result)
# Out:
# [['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['N' 'N']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'N']
#  ['Y' 'Y']
#  ['Y' 'N']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'N']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'N']
#  ['Y' 'N']
#  ['Y' 'Y']
#  ['Y' 'N']
#  ['Y' 'Y']
#  ['N' 'N']
#  ['Y' 'Y']
#  ['N' 'N']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'N']
#  ['N' 'N']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['N' 'Y']
#  ['Y' 'Y']
#  ['Y' 'N']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'N']
#  ['Y' 'Y']
#  ['N' 'N']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['N' 'N']
#  ['N' 'N']
#  ['N' 'N']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['N' 'N']
#  ['Y' 'Y']
#  ['N' 'N']
#  ['N' 'Y']
#  ['N' 'N']
#  ['Y' 'Y']
#  ['Y' 'N']
#  ['N' 'N']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['Y' 'Y']
#  ['N' 'Y']
#  ['Y' 'Y']
#  ['N' 'N']
#  ['N' 'Y']
#  ['Y' 'Y']
#  ['Y' 'Y']
# ...

# %%
from sklearn.metrics import confusion_matrix, accuracy_score,precision_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[19 18]
#  [ 6 80]]
# 0.8048780487804879

# %%
from sklearn.tree import plot_tree
plot_tree(classifier)
# Out:
# [Text(0.26971153846153845, 0.9848484848484849, 'x[4] <= -0.999\nentropy = 0.9\nsamples = 491\nvalue = [155, 336]'),
#  Text(0.09230769230769231, 0.9545454545454546, 'x[2] <= -0.29\nentropy = 0.46\nsamples = 72\nvalue = [65, 7]'),
#  Text(0.07692307692307693, 0.9242424242424242, 'entropy = 0.0\nsamples = 31\nvalue = [31, 0]'),
#  Text(0.1076923076923077, 0.9242424242424242, 'x[2] <= 0.162\nentropy = 0.659\nsamples = 41\nvalue = [34, 7]'),
#  Text(0.07692307692307693, 0.8939393939393939, 'x[0] <= -0.515\nentropy = 0.845\nsamples = 22\nvalue = [16, 6]'),
#  Text(0.06153846153846154, 0.8636363636363636, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.09230769230769231, 0.8636363636363636, 'x[1] <= 0.248\nentropy = 0.792\nsamples = 21\nvalue = [16, 5]'),
#  Text(0.07692307692307693, 0.8333333333333334, 'x[2] <= 0.123\nentropy = 0.918\nsamples = 15\nvalue = [10, 5]'),
# ...

# %%
df.head()
# Out:
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       128.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Loan_Status
# 0             1.0           Y
# 1             1.0           N
# 2             1.0           Y
# 3             1.0           Y
# 4             1.0           Y

# %%
df['Loan_Status'].value_counts()
# Out:
# Loan_Status
# Y    422
# N    192
# Name: count, dtype: int64

# %%
plt.pie(df['Loan_Status'].value_counts(),labels=['Y','N'],autopct="%0.2f")
# Out:
# ([<matplotlib.patches.Wedge at 0x28d3aff8510>,
# ...
#  [Text(-0.6105420895241798, 0.9150072988339757, 'Y'),
#   Text(0.6105420038550106, -0.9150073559970479, 'N')],
#  [Text(-0.33302295792227987, 0.4990948902730776, '68.73'),
#   Text(0.3330229111936421, -0.49909492145293516, '31.27')])

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
sns.pairplot(df,hue='Loan_Status')
# Out:
# C:\Users\Hp\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
numeric_df = df.select_dtypes(include=['number'])
corr_matrix = numeric_df.corr()  # Compute correlation matrix
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier

# %%
svc = SVC(kernel='sigmoid', gamma=1.0)
knc = KNeighborsClassifier()
mnb = MultinomialNB()
dtc = DecisionTreeClassifier(max_depth=5)
lrc = LogisticRegression(solver='liblinear', penalty='l1')
rfc = RandomForestClassifier(n_estimators=50, random_state=2)
abc = AdaBoostClassifier(n_estimators=50, random_state=2)
bc = BaggingClassifier(n_estimators=50, random_state=2)
etc = ExtraTreesClassifier(n_estimators=50, random_state=2)
gbdt = GradientBoostingClassifier(n_estimators=50,random_state=2)
xgb = XGBClassifier(n_estimators=50,random_state=2)

# %%
clfs = {
    'SVC' : svc,
    'KN' : knc, 
    'NB': mnb, 
    'DT': dtc, 
    'LR': lrc, 
    'RF': rfc, 
    'AdaBoost': abc, 
    'BgC': bc, 
    'ETC': etc,
    'GBDT':gbdt,
    'xgb':xgb
}

# %%
def train_classifier(clf,X_train,y_train,X_test,y_test):
    clf.fit(X_train,y_train)
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test,y_pred)
    precision = precision_score(y_test,y_pred)
    
    return accuracy,precision

# %%
y_train_numeric = y_train.map({'N': 0, 'Y': 1})
y_test_numeric = y_test.map({'N': 0, 'Y': 1})

svc = SVC()
svc.fit(X_train, y_train_numeric)

y_pred_numeric = svc.predict(X_test)

y_pred = pd.Series(y_pred_numeric).map({0: 'N', 1: 'Y'})

from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            N       0.73      0.51      0.60        37
#            Y       0.81      0.92      0.86        86
#
#     accuracy                           0.80       123
#    macro avg       0.77      0.72      0.73       123
# weighted avg       0.79      0.80      0.79       123

# %%
import numpy as np
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, precision_score

X_train = np.maximum(0, X_train)
X_test = np.maximum(0, X_test)

accuracy_scores = []
precision_scores = []

for name, clf in clfs.items():

    clf.fit(X_train, y_train_numeric)

    y_pred_numeric = clf.predict(X_test)
    
    current_accuracy = accuracy_score(y_test_numeric, y_pred_numeric)
    current_precision = precision_score(y_test_numeric, y_pred_numeric, pos_label=1)
    
    print("For", name)
    print("Accuracy -", current_accuracy)
    print("Precision -", current_precision)
    
    accuracy_scores.append(current_accuracy)
    precision_scores.append(current_precision)
# Out:
# For SVC
# Accuracy - 0.7886178861788617
# Precision - 0.8333333333333334
# For KN
# Accuracy - 0.7723577235772358
# Precision - 0.8020833333333334
# For NB
# Accuracy - 0.7154471544715447
# Precision - 0.7107438016528925
# For DT
# Accuracy - 0.7804878048780488
# Precision - 0.8105263157894737
# For LR
# Accuracy - 0.8048780487804879
# Precision - 0.8163265306122449
# For RF
# Accuracy - 0.7398373983739838
# Precision - 0.8
# For AdaBoost
# Accuracy - 0.7723577235772358
# Precision - 0.8085106382978723
# For BgC
# Accuracy - 0.7317073170731707
# Precision - 0.797752808988764
# For ETC
# Accuracy - 0.7479674796747967
# Precision - 0.7956989247311828
# For GBDT
# Accuracy - 0.7886178861788617
# Precision - 0.8125
# For xgb
# Accuracy - 0.7642276422764228
# Precision - 0.8202247191011236

# %%
performance_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy':accuracy_scores,'Precision':precision_scores})

# %%
performance_df
# Out:
#    Algorithm  Accuracy  Precision
# 0        SVC  0.788618   0.833333
# 1         KN  0.772358   0.802083
# 2         NB  0.715447   0.710744
# 3         DT  0.780488   0.810526
# 4         LR  0.804878   0.816327
# 5         RF  0.739837   0.800000
# 6   AdaBoost  0.772358   0.808511
# 7        BgC  0.731707   0.797753
# 8        ETC  0.747967   0.795699
# 9       GBDT  0.788618   0.812500
# 10       xgb  0.764228   0.820225

# %%
performance_df1 = pd.melt(performance_df, id_vars = "Algorithm")

# %%
performance_df1
# Out:
#    Algorithm   variable     value
# 0        SVC   Accuracy  0.788618
# 1         KN   Accuracy  0.772358
# 2         NB   Accuracy  0.715447
# 3         DT   Accuracy  0.780488
# 4         LR   Accuracy  0.804878
# 5         RF   Accuracy  0.739837
# 6   AdaBoost   Accuracy  0.772358
# 7        BgC   Accuracy  0.731707
# 8        ETC   Accuracy  0.747967
# 9       GBDT   Accuracy  0.788618
# 10       xgb   Accuracy  0.764228
# 11       SVC  Precision  0.833333
# 12        KN  Precision  0.802083
# 13        NB  Precision  0.710744
# 14        DT  Precision  0.810526
# 15        LR  Precision  0.816327
# 16        RF  Precision  0.800000
# 17  AdaBoost  Precision  0.808511
# 18       BgC  Precision  0.797753
# 19       ETC  Precision  0.795699
# 20      GBDT  Precision  0.812500
# 21       xgb  Precision  0.820225

# %%
sns.catplot(x = 'Algorithm', y='value', 
hue = 'variable',data=performance_df1, kind='bar',height=5)
plt.ylim(0.5,1.0)
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\Users\Hp\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
svc = SVC(kernel='sigmoid', gamma=1.0,probability=True)
mnb = MultinomialNB()
etc = ExtraTreesClassifier(n_estimators=50, random_state=2)

from sklearn.ensemble import VotingClassifier

# %%
voting = VotingClassifier(estimators=[('svm', svc), ('nb', mnb), ('et', etc)],voting='soft')

# %%
voting.fit(X_train,y_train)
# Out:
# VotingClassifier(estimators=[('svm',
#                               SVC(gamma=1.0, kernel='sigmoid',
#                                   probability=True)),
#                              ('nb', MultinomialNB()),
#                              ('et',
#                               ExtraTreesClassifier(n_estimators=50,
#                                                    random_state=2))],
#                  voting='soft')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Define your corpus (list of text documents)
corpus = [
    "This is the first document.",
    "This document is the second document.",
    "And this is the third one.",
    "Is this the first document?"
]

# Define and apply the TfidfVectorizer
tfidf = TfidfVectorizer()
X_tfidf = tfidf.fit_transform(corpus)

# Now you can use X_tfidf for further processing
print(X_tfidf.shape)
# Out:
# (4, 9)

# %%
import pickle
pickle.dump(tfidf,open('vectorizer.pkl','wb'))
pickle.dump(mnb,open('model.pkl','wb'))
